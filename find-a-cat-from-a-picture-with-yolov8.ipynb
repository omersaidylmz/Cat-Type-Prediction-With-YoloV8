# %% [markdown]
# <a href="https://www.kaggle.com/code/mersaidylmaz/find-a-cat-from-a-picture-with-yolov8?scriptVersionId=147230532" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ##  <b> <span style='color:#16C2D5'>|</span> Ultralytics Kütüphanesinin İndirilmesi </b>

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5016.7/8062.4 GB disk)

# %% [markdown]
# ##  <b> <span style='color:#16C2D5'>|</span> Görüntü İşlemede Yardım Edecek Image,YOLO ve Display' in İmport Edilmesi </b>

# %%
from ultralytics import YOLO
from IPython.display import display, Image
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %% [markdown]
# ## <b> <span style='color:#16C2D5'>|</span> Datasetin Sistemden Çekilmesi </b>

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="wOUaBLdp5weZP9mmzP2z")
project = rf.workspace("mer-said-yilmaz").project("cat_detect-se1sb")
dataset = project.version(4).download("yolov8")
# Out:
# /kaggle/working/datasets
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pytoolconfig 1.2.5 requires packaging>=22.0, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.2 which is incompatible.
# A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to cat_detect-4 in yolov8:: 100%|██████████| 674/674 [00:00<00:00, 7715.93it/s]

# %% [markdown]
# ## <b> <span style='color:#16C2D5'>|</span> Modelin Verisetinde ki Etiketlenmiş Veriler İle Eğitilmesi </b>

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8l.pt data={dataset.location}/data.yaml epochs=75 imgsz=800 plots=Tr
# Out:
# /kaggle/working
# ...
# 100%|███████████████████████████████████████| 83.7M/83.7M [00:00<00:00, 230MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# F1_curve.png					  train_batch0.jpg
# PR_curve.png					  train_batch1.jpg
# P_curve.png					  train_batch1235.jpg
# R_curve.png					  train_batch1236.jpg
# args.yaml					  train_batch1237.jpg
# confusion_matrix.png				  train_batch2.jpg
# events.out.tfevents.1697722853.70584477a53f.70.0  val_batch0_labels.jpg
# results.csv					  val_batch0_pred.jpg
# results.png					  weights

# %% [markdown]
# ## <b> <span style='color:#16C2D5'>|</span> Karışıklık Matrisin İncelenmesi Ve Tahminlerin Ön Kontrolü </b>

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /kaggle/working

# %% [markdown]
# ## <b> <span style='color:#16C2D5'>|</span> Loss Değerlerinin Kontrolü </b>

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /kaggle/working

# %% [markdown]
# ## <b> <span style='color:#16C2D5'>|</span>  Verisetinde ki Tahmin Edilen Değerlerin Görselleştirilmesi </b>

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /kaggle/working

# %% [markdown]
# ## <b> <span style='color:#16C2D5'>|</span> Validation İşlemleri </b>

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /kaggle/working
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 268 layers, 43609692 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /kaggle/working/datasets/cat_detect-4/valid/labels.cache... 12 ima
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12         12      0.869      0.882       0.94      0.637
#                british         12          6      0.974          1      0.995      0.657
#                   iran         12          3      0.634      0.667       0.83      0.554
#               scootish         12          3          1      0.981      0.995        0.7
# ...

# %% [markdown]
# ### <b> <span style='color:#16C2D5'>|</span> Validation İşleminden Sonra Tekrar Tahmin İşlemi Yapılması </b>

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
